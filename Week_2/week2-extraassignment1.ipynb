# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
name=str(input(""))
print("Enter your institue name?",name)
# Out:
#  HOPE AI
# Enter your institue name? HOPE AI

# %%
name=str(input("Name"))
age=int(input("age"))
s_name=str(input("School name"))
degree=str(input("degree"))
print("Enter your name:",name)
print("Enter your age:",age)
print("Enter your school name:",s_name)
print("Enter your drgree:",degree)
# Out:
# Name Raj
# age 15
# School name Guru school
# degree B.E CSE
# Enter your name: Raj
# Enter your age: 15
# Enter your school name: Guru school
# Enter your drgree: B.E CSE

# %%
a=43
b=34
print("a=43")
print("b=34")
print("add =",(a+b))
# Out:
# a=43
# b=34
# add = 77

# %%
a=43
b=34
print("a=43")
print("b=34")
print("sub =",(a-b))
# Out:
# a=43
# b=34
# sub = 9

# %%
a=63
b=97
print("a=63")
print("b=97")
print("mul =",(a*b))
# Out:
# a=63
# b=97
# mul = 6111

# %%
a=76
b=31
print("a=76")
print("b=31")
print("div =",(a/b))
# Out:
# a=76
# b=31
# div = 2.4516129032258065

# %%
a=76
b=31
print("a=76")
print("b=31")
print("Float div =",(a//b))
# Out:
# a=76
# b=31
# Float div = 2

# %%
a=76
b=31
print("a=76")
print("b=31")
print("Modulo =",(a%b))
# Out:
# a=76
# b=31
# Modulo = 14

# %%
a=4
b=4
print("a=4")
print("b=4")
print("Power =",(a**b))
# Out:
# a=4
# b=4
# Power = 256
